# %%
import os

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")

# %%
res= llm.invoke("who is pm of netherlands")
print(res.content)
# Out:
# [{'type': 'text', 'text': 'The Prime Minister of the Netherlands is **Dick Schoof**. He took office on July 2, 2024, succeeding Mark Rutte. Schoof is an independent politician (not affiliated with a specific political party) who leads a right-leaning coalition government.', 'extras': {'signature': 'El4KXAERTTIPEi4KDja71DwPkMAclX8e4vftIlOs5w1ebBU+ncujG5atxSNcj/nDMRsquHF4YBp8PdNsWSKF4WYOPvDGDJCGEKYA7PkO4byHC+IX/fz+kYmaDxcl5KYG'}}]
